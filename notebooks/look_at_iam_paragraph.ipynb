# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

try:
    import text_recognizer
except ImportError:
    sys.path.append('..')

from text_recognizer.datasets.iam_dataset import IamDataset
from text_recognizer.datasets.iam_paragraphs_dataset import IAMParagraphsDataset
# Out:
# 2025-03-07 23:16:54.343529: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-07 23:16:54.379597: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-07 23:16:54.379636: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-07 23:16:54.380966: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-07 23:16:54.387601: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-07 23:16:54.388412: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-07 23:16:55.282591: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset = IamDataset()
print(dataset)
# Out:
# IAM Dataset
# Num forms: 1539

# %%
paragraphs_dataset = IAMParagraphsDataset()
paragraphs_dataset.load_or_generate_data()
print(paragraphs_dataset)
# Out:
# Loading IAM paragraph crops and ground truth from image files...
# IAM Paragraphs Dataset
# Num classes: 3
# Train: (1229, 256, 256) (1229, 256, 256, 3)
# Test: (308, 256, 256) (308, 256, 256, 3)

# %%
for ind in range(10):
    x = paragraphs_dataset.x_train[ind]
    y = paragraphs_dataset.y_train[ind]
    fig = plt.figure(figsize=(10,4))
    ax1 = fig.add_subplot(121)
    ax1.matshow(x, cmap='gray')
    ax2 = fig.add_subplot(122)
    ax2.matshow(y.argmax(-1), cmap='gray')
